# %%
import pandas as pd

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
dataset=pd.read_csv("vehicle_maintenance_data.csv")
print(dataset)
# Out:
#       Vehicle_Model  Mileage Maintenance_History  Reported_Issues  \
# 0             Truck    58765                Good                0
# 1               Van    60353             Average                1
# 2               Bus    68072                Poor                0
# 3               Bus    60849             Average                4
# 4               Bus    45742                Poor                5
# ...             ...      ...                 ...              ...
# 49995           Car    77229                Good                3
# 49996         Truck    54742                Good                4
# 49997           Van    75601                Poor                0
# 49998           Car    66181                Good                1
# 49999           Car    71605                Poor                0
#
#        Vehicle_Age Fuel_Type Transmission_Type  Engine_Size  Odometer_Reading  \
# 0                4  Electric         Automatic         2000             28524
# 1                7  Electric         Automatic         2500            133630
# 2                2  Electric         Automatic         1500             34022
# 3                5    Petrol         Automatic         2500             81636
# 4                1    Petrol            Manual         2000             97162
# ...            ...       ...               ...          ...               ...
# 49995            6    Diesel         Automatic         2500             97404
# 49996            4    Diesel            Manual          800             13421
# 49997            4  Electric         Automatic         1500            124851
# 49998            7  Electric            Manual         2500            103182
# 49999           10    Petrol            Manual         2000             65721
#
#       Last_Service_Date Warranty_Expiry_Date Owner_Type  Insurance_Premium  \
# 0            2023-11-23           2025-06-24     Second              20782
# 1            2023-09-21           2025-06-04     Second              23489
# 2            2023-06-27           2025-04-27      First              17979
# 3            2023-08-24           2025-11-05     Second               6220
# 4            2023-05-25           2025-09-14      Third              16446
# ...                 ...                  ...        ...                ...
# 49995        2023-11-24           2025-09-15      Third               5217
# 49996        2023-07-14           2025-01-21     Second              15856
# 49997        2023-09-09           2024-11-09      First               6019
# 49998        2023-08-26           2025-05-22      Third               5030
# 49999        2023-07-25           2024-06-06      Third               9171
#
#        Service_History  Accident_History  Fuel_Efficiency Tire_Condition  \
# 0                    6                 3        13.622204            New
# 1                    7                 0        13.625307            New
# 2                    7                 0        14.306302            New
# 3                    7                 3        18.709467            New
# 4                    6                 2        16.977482           Good
# ...                ...               ...              ...            ...
# 49995                4                 1        10.357298            New
# 49996                4                 1        14.924022       Worn Out
# 49997               10                 0        19.859243       Worn Out
# 49998                4                 3        10.720555            New
# 49999                6                 3        16.328945           Good
#
#       Brake_Condition Battery_Status  Need_Maintenance
# 0                 New           Weak                 1
# 1                 New           Weak                 1
# 2                Good           Weak                 1
# 3            Worn Out            New                 1
# 4                Good           Weak                 1
# ...               ...            ...               ...
# 49995            Good           Weak                 1
# 49996             New           Good                 1
# 49997        Worn Out           Weak                 1
# 49998            Good           Weak                 1
# 49999             New           Good                 0
#
# [50000 rows x 20 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Vehicle_Model         50000 non-null  object
#  1   Mileage               50000 non-null  int64
#  2   Maintenance_History   50000 non-null  object
#  3   Reported_Issues       50000 non-null  int64
#  4   Vehicle_Age           50000 non-null  int64
#  5   Fuel_Type             50000 non-null  object
#  6   Transmission_Type     50000 non-null  object
#  7   Engine_Size           50000 non-null  int64
#  8   Odometer_Reading      50000 non-null  int64
#  9   Last_Service_Date     50000 non-null  object
#  10  Warranty_Expiry_Date  50000 non-null  object
#  11  Owner_Type            50000 non-null  object
#  12  Insurance_Premium     50000 non-null  int64
#  13  Service_History       50000 non-null  int64
#  14  Accident_History      50000 non-null  int64
#  15  Fuel_Efficiency       50000 non-null  float64
#  16  Tire_Condition        50000 non-null  object
#  17  Brake_Condition       50000 non-null  object
#  18  Battery_Status        50000 non-null  object
#  19  Need_Maintenance      50000 non-null  int64
# dtypes: float64(1), int64(9), object(10)
# memory usage: 7.6+ MB

# %%
dataset.isnull().sum()
# Out:
# Vehicle_Model           0
# Mileage                 0
# Maintenance_History     0
# Reported_Issues         0
# Vehicle_Age             0
# Fuel_Type               0
# Transmission_Type       0
# Engine_Size             0
# Odometer_Reading        0
# Last_Service_Date       0
# Warranty_Expiry_Date    0
# Owner_Type              0
# Insurance_Premium       0
# Service_History         0
# Accident_History        0
# Fuel_Efficiency         0
# Tire_Condition          0
# Brake_Condition         0
# Battery_Status          0
# Need_Maintenance        0
# dtype: int64

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
print(dataset)
# Out:
#        Mileage  Reported_Issues  Vehicle_Age  Engine_Size  Odometer_Reading  \
# 0        58765                0            4         2000             28524
# 1        60353                1            7         2500            133630
# 2        68072                0            2         1500             34022
# 3        60849                4            5         2500             81636
# 4        45742                5            1         2000             97162
# ...        ...              ...          ...          ...               ...
# 49995    77229                3            6         2500             97404
# 49996    54742                4            4          800             13421
# 49997    75601                0            4         1500            124851
# 49998    66181                1            7         2500            103182
# 49999    71605                0           10         2000             65721
#
#        Insurance_Premium  Service_History  Accident_History  Fuel_Efficiency  \
# 0                  20782                6                 3        13.622204
# 1                  23489                7                 0        13.625307
# 2                  17979                7                 0        14.306302
# 3                   6220                7                 3        18.709467
# 4                  16446                6                 2        16.977482
# ...                  ...              ...               ...              ...
# 49995               5217                4                 1        10.357298
# 49996              15856                4                 1        14.924022
# 49997               6019               10                 0        19.859243
# 49998               5030                4                 3        10.720555
# 49999               9171                6                 3        16.328945
#
#        Need_Maintenance  ...  Warranty_Expiry_Date_2026-03-28  \
# 0                     1  ...                            False
# 1                     1  ...                            False
# 2                     1  ...                            False
# 3                     1  ...                            False
# 4                     1  ...                            False
# ...                 ...  ...                              ...
# 49995                 1  ...                            False
# 49996                 1  ...                            False
# 49997                 1  ...                            False
# 49998                 1  ...                            False
# 49999                 0  ...                            False
#
#        Warranty_Expiry_Date_2026-03-29  Owner_Type_Second  Owner_Type_Third  \
# 0                                False               True             False
# 1                                False               True             False
# 2                                False              False             False
# 3                                False               True             False
# 4                                False              False              True
# ...                                ...                ...               ...
# 49995                            False              False              True
# 49996                            False               True             False
# 49997                            False              False             False
# 49998                            False              False              True
# 49999                            False              False              True
#
#        Tire_Condition_New  Tire_Condition_Worn Out  Brake_Condition_New  \
# 0                    True                    False                 True
# 1                    True                    False                 True
# 2                    True                    False                False
# 3                    True                    False                False
# 4                   False                    False                False
# ...                   ...                      ...                  ...
# 49995                True                    False                False
# 49996               False                     True                 True
# 49997               False                     True                False
# 49998                True                    False                False
# 49999               False                    False                 True
#
#        Brake_Condition_Worn Out  Battery_Status_New  Battery_Status_Weak
# 0                         False               False                 True
# 1                         False               False                 True
# 2                         False               False                 True
# 3                          True                True                False
# 4                         False               False                 True
# ...                         ...                 ...                  ...
# 49995                     False               False                 True
# 49996                     False               False                False
# 49997                      True               False                 True
# 49998                     False               False                 True
# 49999                     False               False                False
#
# [50000 rows x 1063 columns]

# %%
independent=dataset[['Mileage', 'Reported_Issues', 'Vehicle_Age', 'Engine_Size',
       'Odometer_Reading', 'Insurance_Premium', 'Service_History',
       'Accident_History', 'Fuel_Efficiency', 
       'Owner_Type_Second', 'Owner_Type_Third', 'Tire_Condition_New',
       'Tire_Condition_Worn Out', 'Brake_Condition_New',
       'Brake_Condition_Worn Out', 'Battery_Status_New',
       'Battery_Status_Weak']]
print(independent)
# Out:
#        Mileage  Reported_Issues  Vehicle_Age  Engine_Size  Odometer_Reading  \
# 0        58765                0            4         2000             28524
# 1        60353                1            7         2500            133630
# 2        68072                0            2         1500             34022
# 3        60849                4            5         2500             81636
# 4        45742                5            1         2000             97162
# ...        ...              ...          ...          ...               ...
# 49995    77229                3            6         2500             97404
# 49996    54742                4            4          800             13421
# 49997    75601                0            4         1500            124851
# 49998    66181                1            7         2500            103182
# 49999    71605                0           10         2000             65721
#
#        Insurance_Premium  Service_History  Accident_History  Fuel_Efficiency  \
# 0                  20782                6                 3        13.622204
# 1                  23489                7                 0        13.625307
# 2                  17979                7                 0        14.306302
# 3                   6220                7                 3        18.709467
# 4                  16446                6                 2        16.977482
# ...                  ...              ...               ...              ...
# 49995               5217                4                 1        10.357298
# 49996              15856                4                 1        14.924022
# 49997               6019               10                 0        19.859243
# 49998               5030                4                 3        10.720555
# 49999               9171                6                 3        16.328945
#
#        Owner_Type_Second  Owner_Type_Third  Tire_Condition_New  \
# 0                   True             False                True
# 1                   True             False                True
# 2                  False             False                True
# 3                   True             False                True
# 4                  False              True               False
# ...                  ...               ...                 ...
# 49995              False              True                True
# 49996               True             False               False
# 49997              False             False               False
# 49998              False              True                True
# 49999              False              True               False
#
#        Tire_Condition_Worn Out  Brake_Condition_New  Brake_Condition_Worn Out  \
# 0                        False                 True                     False
# 1                        False                 True                     False
# 2                        False                False                     False
# 3                        False                False                      True
# 4                        False                False                     False
# ...                        ...                  ...                       ...
# 49995                    False                False                     False
# 49996                     True                 True                     False
# 49997                     True                False                      True
# 49998                    False                False                     False
# 49999                    False                 True                     False
#
#        Battery_Status_New  Battery_Status_Weak
# 0                   False                 True
# 1                   False                 True
# 2                   False                 True
# 3                    True                False
# 4                   False                 True
# ...                   ...                  ...
# 49995               False                 True
# 49996               False                False
# 49997               False                 True
# 49998               False                 True
# 49999               False                False
#
# [50000 rows x 17 columns]

# %%
dependent=dataset[["Need_Maintenance"]] 
print(dependent)
# Out:
#        Need_Maintenance
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1
# ...                 ...
# 49995                 1
# 49996                 1
# 49997                 1
# 49998                 1
# 49999                 0
#
# [50000 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(independent, dependent, test_size=0.30,random_state=0)

# %%
x_train
# Out:
#        Mileage  Reported_Issues  Vehicle_Age  Engine_Size  Odometer_Reading  \
# 17967    71666                1            9         1500            127603
# 32391    70690                5            7         2000            137412
# 9341     69697                4            3         2000             70402
# 7929     72955                5            1         1000            130125
# 46544    42592                1           10         2500             86617
# ...        ...              ...          ...          ...               ...
# 21243    61691                2            2         2500            122004
# 45891    70855                4            1          800             90137
# 42613    60833                2            7         1500            100110
# 43567    53503                2            9         1000             59608
# 2732     53330                4            9          800             17440
#
#        Insurance_Premium  Service_History  Accident_History  Fuel_Efficiency  \
# 17967              25220                5                 1        17.479013
# 32391               6855                7                 3        18.377161
# 9341               27790                3                 3        19.979528
# 7929               27765                7                 3        18.069142
# 46544              28456                7                 1        17.087035
# ...                  ...              ...               ...              ...
# 21243              14103                2                 2        12.177988
# 45891              20460                5                 3        16.519220
# 42613              17478                9                 2        10.663651
# 43567              17978                6                 0        17.039619
# 2732               26215                3                 2        11.072476
#
#        Owner_Type_Second  Owner_Type_Third  Tire_Condition_New  \
# 17967              False             False               False
# 32391              False              True               False
# 9341                True             False                True
# 7929               False             False                True
# 46544              False             False               False
# ...                  ...               ...                 ...
# 21243               True             False                True
# 45891              False             False               False
# 42613              False              True                True
# 43567              False              True                True
# 2732               False              True                True
#
#        Tire_Condition_Worn Out  Brake_Condition_New  Brake_Condition_Worn Out  \
# 17967                    False                False                     False
# 32391                    False                 True                     False
# 9341                     False                False                      True
# 7929                     False                False                      True
# 46544                     True                False                      True
# ...                        ...                  ...                       ...
# 21243                    False                False                     False
# 45891                    False                 True                     False
# 42613                    False                False                      True
# 43567                    False                False                     False
# 2732                     False                False                      True
#
#        Battery_Status_New  Battery_Status_Weak
# 17967               False                False
# 32391               False                 True
# 9341                 True                False
# 7929                False                 True
# 46544               False                False
# ...                   ...                  ...
# 21243                True                False
# 45891               False                 True
# 42613                True                False
# 43567               False                 True
# 2732                False                False
#
# [35000 rows x 17 columns]

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)
x_train
# Out:
# array([[ 1.16423527, -0.87415278,  1.21674369, ..., -0.71117152,
#         -0.70744016, -0.70734923],
#        [ 1.0965471 ,  1.46838859,  0.52137644, ..., -0.71117152,
#         -0.70744016,  1.41372883],
#        [ 1.02767994,  0.88275325, -0.86935808, ...,  1.40613055,
#          1.41354712, -0.70734923],
#        ...,
#        [ 0.41293821, -0.28851743,  0.52137644, ...,  1.40613055,
#          1.41354712, -0.70734923],
#        [-0.09541657, -0.28851743,  1.21674369, ..., -0.71117152,
#         -0.70744016,  1.41372883],
#        [-0.10741458,  0.88275325,  1.21674369, ...,  1.40613055,
#         -0.70744016, -0.70734923]], shape=(35000, 17))

# %%
from sklearn.ensemble import RandomForestClassifier
classifier= RandomForestClassifier(n_estimators=50,criterion='gini',random_state=0)
classifier.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=50, random_state=0)

# %%
y_pred=classifier.predict(x_test)

# %%
import pickle
filename="finalized_model_Ft.sav"
pickle.dump(classifier,open(filename,'wb'))

# %%
loaded_model=pickle.load(open("finalized_model_Forest.sav",'rb'))
result=loaded_model.predict([[12,43,56,689,7,898,368,234,45,67,89,123,45,67,89,45,45]])
print(result)
# Out:
# [1]

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# [[ 2524   361]
#  [  314 11801]]

# %%
from sklearn.metrics import classification_report
report=classification_report(y_test,y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.87      0.88      2885
#            1       0.97      0.97      0.97     12115
#
#     accuracy                           0.95     15000
#    macro avg       0.93      0.92      0.93     15000
# weighted avg       0.95      0.95      0.95     15000
